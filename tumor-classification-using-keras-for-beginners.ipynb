# %% [markdown]
# # Import Statements

# %%
import os
import keras 
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from PIL import Image
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('dark_background')
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder 
from tensorflow.keras.callbacks import TensorBoard, ModelCheckpoint

# %% [markdown]
# # One Hot Encoding the Target Classes

# %%
encoder = OneHotEncoder()
encoder.fit([[0], [1]]) 

# 0 - Tumor
# 1 - Normal
# Out:
# OneHotEncoder()

# %% [markdown]
# # Creating 3 Important Lists --
# 1. data -for storing image data in numpy array form
# 2. paths - for storing paths of all the images
# 3. result -for storing one hot encoded form of target class whether normal or tumor

# %%
# This cell updates result list for images with tumor

data = []
paths = []
result = []

for r, d, f in os.walk(r'../input/brain-mri-images-for-brain-tumor-detection/yes'):
    for file in f:
        if '.jpg' in file:
            paths.append(os.path.join(r, file))

for path in paths:
    img = Image.open(path)
    img = img.resize((128,128))
    img = np.array(img)
    if(img.shape == (128,128,3)):
        data.append(np.array(img))
        result.append(encoder.transform([[0]]).toarray())

# %%
# This cell updates result list for images without tumor

paths = []
for r, d, f in os.walk(r"../input/brain-mri-images-for-brain-tumor-detection/no"):
    for file in f:
        if '.jpg' in file:
            paths.append(os.path.join(r, file))

for path in paths:
    img = Image.open(path)
    img = img.resize((128,128))
    img = np.array(img)
    if(img.shape == (128,128,3)):
        data.append(np.array(img))
        result.append(encoder.transform([[1]]).toarray())

# %%
data = np.array(data)
data.shape
# Out:
# (139, 128, 128, 3)

# %%
result = np.array(result)
result = result.reshape(139,2)

# %% [markdown]
# # Splitting the Data into Training & Testing

# %%
x_train,x_test,y_train,y_test = train_test_split(data, result, test_size=0.2, shuffle=True, random_state=0)

# %% [markdown]
# # Model Building

# %% [markdown]
# Batch normalization is a technique for training very deep neural networks that standardizes the inputs to a layer for each mini-batch. This has the effect of stabilizing the learning process and dramatically reducing the number of training epochs required to train deep networks.

# %%
model = Sequential()

model.add(Conv2D(32, kernel_size=(2, 2), input_shape=(128, 128, 3), padding = 'Same'))
model.add(Conv2D(32, kernel_size=(2, 2),  activation ='relu', padding = 'Same'))


model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(64, kernel_size = (2,2), activation ='relu', padding = 'Same'))
model.add(Conv2D(64, kernel_size = (2,2), activation ='relu', padding = 'Same'))

model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2), strides=(2,2)))
model.add(Dropout(0.25))

model.add(Flatten())

model.add(Dense(512, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(2, activation='softmax'))

model.compile(loss = "categorical_crossentropy", optimizer='Adamax')
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 128, 128, 32)      416
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 128, 128, 32)      4128
# _________________________________________________________________
# batch_normalization (BatchNo (None, 128, 128, 32)      128
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 64, 64, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 64, 64, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 64, 64, 64)        8256
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 64, 64, 64)        16448
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 64, 64, 64)        256
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 32, 32, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 32, 32, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 65536)             0
# _________________________________________________________________
# dense (Dense)                (None, 512)               33554944
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 1026
# =================================================================
# Total params: 33,585,602
# Trainable params: 33,585,410
# Non-trainable params: 192
# _________________________________________________________________
# None

# %%
y_train.shape
# Out:
# (111, 2)

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
history = model.fit(x_train, y_train, epochs = 30, batch_size = 40, verbose = 1,validation_data = (x_test, y_test))
# Out:
# Epoch 1/30
# 3/3 [==============================] - 3s 1s/step - loss: 3.4260e-07 - accuracy: 1.0000 - val_loss: 1.1553 - val_accuracy: 0.8571
# Epoch 2/30
# 3/3 [==============================] - 3s 958ms/step - loss: 3.9587e-05 - accuracy: 1.0000 - val_loss: 1.5624 - val_accuracy: 0.8571
# Epoch 3/30
# 3/3 [==============================] - 3s 904ms/step - loss: 6.5003e-07 - accuracy: 1.0000 - val_loss: 1.8317 - val_accuracy: 0.8571
# Epoch 4/30
# 3/3 [==============================] - 3s 902ms/step - loss: 0.1303 - accuracy: 0.9910 - val_loss: 2.2880 - val_accuracy: 0.8214
# Epoch 5/30
# 3/3 [==============================] - 3s 952ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 2.2176 - val_accuracy: 0.7857
# Epoch 6/30
# 3/3 [==============================] - 3s 926ms/step - loss: 0.0185 - accuracy: 0.9910 - val_loss: 3.9714 - val_accuracy: 0.7143
# Epoch 7/30
# 3/3 [==============================] - 3s 924ms/step - loss: 1.2166 - accuracy: 0.9009 - val_loss: 2.8117 - val_accuracy: 0.7500
# Epoch 8/30
# 3/3 [==============================] - 3s 959ms/step - loss: 1.3087 - accuracy: 0.9009 - val_loss: 2.1244 - val_accuracy: 0.8214
# Epoch 9/30
# 3/3 [==============================] - 3s 914ms/step - loss: 1.4317 - accuracy: 0.8919 - val_loss: 3.8618 - val_accuracy: 0.6429
# Epoch 10/30
# 3/3 [==============================] - 3s 919ms/step - loss: 1.7028 - accuracy: 0.8739 - val_loss: 2.2134 - val_accuracy: 0.8214
# Epoch 11/30
# 3/3 [==============================] - 3s 1s/step - loss: 1.4594 - accuracy: 0.8919 - val_loss: 3.5673 - val_accuracy: 0.7143
# Epoch 12/30
# 3/3 [==============================] - 3s 920ms/step - loss: 1.6433 - accuracy: 0.8829 - val_loss: 3.9965 - val_accuracy: 0.7143
# Epoch 13/30
# 3/3 [==============================] - 3s 984ms/step - loss: 1.1864 - accuracy: 0.8919 - val_loss: 4.8996 - val_accuracy: 0.6429
# Epoch 14/30
# 3/3 [==============================] - 3s 943ms/step - loss: 1.4380 - accuracy: 0.9009 - val_loss: 3.9950 - val_accuracy: 0.6786
# Epoch 15/30
# 3/3 [==============================] - 3s 965ms/step - loss: 1.1481 - accuracy: 0.9189 - val_loss: 3.4164 - val_accuracy: 0.7500
# Epoch 16/30
# 3/3 [==============================] - 3s 966ms/step - loss: 0.7723 - accuracy: 0.9369 - val_loss: 6.7282 - val_accuracy: 0.5357
# Epoch 17/30
# 3/3 [==============================] - 3s 905ms/step - loss: 2.0158 - accuracy: 0.8468 - val_loss: 6.7721 - val_accuracy: 0.5357
# Epoch 18/30
# 3/3 [==============================] - 3s 926ms/step - loss: 1.0786 - accuracy: 0.9189 - val_loss: 2.0211 - val_accuracy: 0.8571
# Epoch 19/30
# 3/3 [==============================] - 3s 910ms/step - loss: 1.4863 - accuracy: 0.8919 - val_loss: 1.9170 - val_accuracy: 0.8571
# Epoch 20/30
# 3/3 [==============================] - 3s 937ms/step - loss: 1.0208 - accuracy: 0.9279 - val_loss: 2.5652 - val_accuracy: 0.8214
# Epoch 21/30
# 3/3 [==============================] - 3s 917ms/step - loss: 0.9579 - accuracy: 0.9279 - val_loss: 4.8356 - val_accuracy: 0.6429
# Epoch 22/30
# 3/3 [==============================] - 3s 900ms/step - loss: 2.6227 - accuracy: 0.8108 - val_loss: 3.6397 - val_accuracy: 0.7500
# Epoch 23/30
# 3/3 [==============================] - 3s 956ms/step - loss: 0.6106 - accuracy: 0.9459 - val_loss: 2.7827 - val_accuracy: 0.7143
# Epoch 24/30
# 3/3 [==============================] - 3s 902ms/step - loss: 1.4840 - accuracy: 0.8919 - val_loss: 3.0806 - val_accuracy: 0.7857
# Epoch 25/30
# 3/3 [==============================] - 3s 931ms/step - loss: 2.1376 - accuracy: 0.8468 - val_loss: 3.2865 - val_accuracy: 0.7857
# Epoch 26/30
# 3/3 [==============================] - 3s 928ms/step - loss: 2.0667 - accuracy: 0.8468 - val_loss: 4.7260 - val_accuracy: 0.6786
# Epoch 27/30
# 3/3 [==============================] - 3s 985ms/step - loss: 1.3834 - accuracy: 0.9009 - val_loss: 3.8274 - val_accuracy: 0.6786
# Epoch 28/30
# 3/3 [==============================] - 3s 1s/step - loss: 0.6909 - accuracy: 0.9550 - val_loss: 4.5145 - val_accuracy: 0.6786
# Epoch 29/30
# 3/3 [==============================] - 3s 928ms/step - loss: 0.5533 - accuracy: 0.9640 - val_loss: 3.5155 - val_accuracy: 0.7500
# Epoch 30/30
# 3/3 [==============================] - 3s 914ms/step - loss: 0.7561 - accuracy: 0.9279 - val_loss: 2.7244 - val_accuracy: 0.8214

# %% [markdown]
# # Plotting Losses and Accuracies

# %%
# Loss
plt.plot(history.history['loss'], label='Train')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss')
plt.legend()
plt.show()

# %%
# Accuracy
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Acc')
plt.title('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# # Just Checking the Model

# %%
def names(number):
    if number==0:
        return 'Its a Tumor'
    else:
        return 'No, Its not a tumor'

# %%
from matplotlib.pyplot import imshow
img = Image.open(r"../input/brain-mri-images-for-brain-tumor-detection/no/N17.jpg")
x = np.array(img.resize((128,128)))
x = x.reshape(1,128,128,3)
res = model.predict_on_batch(x)
classification = np.where(res == np.amax(res))[1][0]
imshow(img)
print(str(res[0][classification]*100) + '% Confidence This Is ' + names(classification))
# Out:
# 100.0% Confidence This Is No, Its not a tumor

# %%
from matplotlib.pyplot import imshow
img = Image.open(r"../input/brain-mri-images-for-brain-tumor-detection/yes/Y3.jpg")
x = np.array(img.resize((128,128)))
x = x.reshape(1,128,128,3)
res = model.predict_on_batch(x)
classification = np.where(res == np.amax(res))[1][0]
imshow(img)
print(str(res[0][classification]*100) + '% Confidence This Is A ' + names(classification))
# Out:
# 100.0% Confidence This Is A Its a Tumor

# %% [markdown]
# # Thats It !!
